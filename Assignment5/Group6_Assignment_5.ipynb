# %% [markdown]
# # Importing Necessary Modules

# %%
from google.colab import drive
from tensorflow.keras.utils import plot_model
import os
import cv2
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import vgg16, ResNet50
from keras.layers import Conv2D, Input, Dense, Activation, MaxPooling2D, Flatten, AveragePooling2D, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from keras.utils import to_categorical
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Fetching Peace and Thumbs Up Data, Labeling Peace as 0, and Thumbs Up as 1

# %%
#reading data and labeling it
DIRECTORY = '/content/drive/MyDrive/thumbsup_peace'
CATEGORIES = ['peace_test', 'peace_train', 'thumbsup_test', 'thumbsup_train']
train_data = []
test_data = []
test_count = 0
train_count = 0
for category in CATEGORIES:
  folder = os.path.join(DIRECTORY, category)
  label = CATEGORIES.index(category) // 2
  # print(label)
  splited_name = category.split('_')
  # print(splited_name[1])

  if(splited_name[1] == "train"):
    # print(category)
      for img in os.listdir(folder):
        image = os.path.join(folder, img)
        image_arr = cv2.imread(image)
        image_arr = cv2.resize(image_arr, (224, 224))
        train_data.append([image_arr, label])
        train_count = train_count+1
  else:
    # print("test")
    for img in os.listdir(folder):
      image = os.path.join(folder, img)
      image_arr = cv2.imread(image)
      image_arr = cv2.resize(image_arr, (224, 224))
      test_data.append([image_arr, label])
      test_count = test_count+1

print('Number of total train data: ', train_count)
print('Number of test data: ', test_count)
# Out:
# Number of total train data:  650
# Number of test data:  161

# %% [markdown]
# # Making np array X_train_val and Y_train_val from train data

# %%
#making x and y from read data and label
random.shuffle(train_data)
x_train_val = []
y_train_val = []

for features,label in train_data:
  x_train_val.append(features)
  y_train_val.append(label)

#converitn x and y list to np array
x_train_val = np.array(x_train_val)
y_train_val = np.array(y_train_val)

# %% [markdown]
# # Making np array x_tes and y_test from test data

# %%
#making x and y from read data and label
random.shuffle(test_data)
x_test = []
y_test = []

for features,label in test_data:
  x_test.append(features)
  y_test.append(label)

#converitn x and y list to np array
x_test = np.array(x_test)
y_test = np.array(y_test)
print(len(y_test))
# Out:
# 161

# %% [markdown]
# # Plotting X_train_val

# %%
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_train_val Intensities Before Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# # Plotting X_test

# %%
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_test Intensities Before Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# #Normalizing x_train_val and Plotting

# %%
#normalizing x
x_train_val = x_train_val/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_train_val Pixel Intensities After Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# #Normalizing x_test and Plotting

# %%
#normalizing x
x_test = x_test/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_test Pixel Intensities After Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# # Splitting Train and Validation Set

# %%
# x_train, x_val, y_train, y_val  = train_test_split(x_train_val, y_train_val, test_size=0.1)
x_train = x_train_val[:int(len(x_train_val)*.9)]
x_val = x_train_val[-int(len(x_train_val)*.1):]
y_train = y_train_val[:int(len(y_train_val)*.9)]
y_val = y_train_val[-int(len(y_train_val)*.1):]

# %% [markdown]
# # Plotting y_train, y_val and y_test

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_train, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Train Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')

# Get the counts of objects in each class
counts = np.bincount(y_train)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_val, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Validation Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')
counts = np.bincount(y_val)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_test, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Test Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')
counts = np.bincount(y_test)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Printing The Shapes of Train, Test and Validation Data

# %%
print('Shape of x_train', np.shape(x_train))
print('Shape of x_val', np.shape(x_val))
print('Shape of x_test', np.shape(x_test))
print('Shape of y_train', np.shape(y_train))
print('Shape of y_val', np.shape(y_val))
print('Shape of y_test', np.shape(y_test))
# Out:
# Shape of x_train (585, 224, 224, 3)
# Shape of x_val (65, 224, 224, 3)
# Shape of x_test (161, 224, 224, 3)
# Shape of y_train (585,)
# Shape of y_val (65,)
# Shape of y_test (161,)

# %% [markdown]
# # Extending Vgg16

# %%
vgg16_model = tf.keras.applications.VGG16(
    weights='imagenet',  # You can use 'imagenet' to load ImageNet pre-trained weights
    include_top=False,   # Exclude the top (fully connected) layers
    input_shape=(224, 224, 3)  # Specify the input shape of your images
)


model = tf.keras.models.Sequential()
model.add(vgg16_model)
model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(2, activation='sigmoid'))

model.layers[0].trainable = False
model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.Adam(
    learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14764866 (56.32 MB)
# Trainable params: 50178 (196.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# # Showing Model Architecture

# %%
# Plot and display the model architecture in the notebook
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Trainning The model with x and y

# %%
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=16)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 14s 169ms/step - loss: 0.3813 - accuracy: 0.8171 - val_loss: 0.1474 - val_accuracy: 0.9385
# Epoch 2/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0786 - accuracy: 0.9726 - val_loss: 0.0895 - val_accuracy: 0.9538
# Epoch 3/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0335 - accuracy: 0.9932 - val_loss: 0.0923 - val_accuracy: 0.9846
# Epoch 4/20
# 37/37 [==============================] - 3s 68ms/step - loss: 0.0314 - accuracy: 0.9880 - val_loss: 0.1189 - val_accuracy: 0.9538
# Epoch 5/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0196 - accuracy: 0.9949 - val_loss: 0.0984 - val_accuracy: 0.9692
# Epoch 6/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0131 - accuracy: 0.9983 - val_loss: 0.1011 - val_accuracy: 0.9692
# Epoch 7/20
# 37/37 [==============================] - 2s 68ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9538
# Epoch 8/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0092 - accuracy: 0.9983 - val_loss: 0.0857 - val_accuracy: 0.9538
# Epoch 9/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9692
# Epoch 10/20
# 37/37 [==============================] - 3s 68ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9692
# Epoch 11/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9692
# Epoch 12/20
# 37/37 [==============================] - 2s 68ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9538
# Epoch 13/20
# 37/37 [==============================] - 3s 71ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9692
# Epoch 14/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9692
# Epoch 15/20
# 37/37 [==============================] - 3s 68ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9538
# Epoch 16/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0893 - val_accuracy: 0.9692
# Epoch 17/20
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9538
# Epoch 18/20
# 37/37 [==============================] - 3s 70ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9692
# Epoch 19/20
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9538
# Epoch 20/20
# 37/37 [==============================] - 3s 71ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9692

# %%
performance_dict = history.history
print(performance_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Check The Learning Curves

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss', fontsize=16)

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# # Evaluate The Model On Validation Set

# %%
scores = model.evaluate(x_val, y_val)
# print(model.metrics_names)
print('Evaluating The Model On Validation Data')
print(model.metrics_names[1], scores[1]*100)
# Out:
# 3/3 [==============================] - 7s 69ms/step - loss: 0.0957 - accuracy: 0.9692
# Evaluating The Model On Validation Data
# accuracy 96.92307710647583

# %% [markdown]
# # Check What the model actually predicts In Validation Data

# %%
plt.imshow(x_val[26])
print(y_val[26])
# Out:
# 0

# %% [markdown]
# # Check What the model predicts in Test data

# %%
prediction = model.predict(x_test)
# Out:
# 6/6 [==============================] - 1s 105ms/step

# %%
prediction[1]
# Out:
# array([0.01802415, 0.97582066], dtype=float32)

# %%
y_test[1]
# Out:
# 1

# %%
y_predicted = []
# length = prediction.shape[0]
for i in range(prediction.shape[0]):
  if(prediction[i][0] > prediction[i][1]):
    y_predicted.append(0)
  else:
    y_predicted.append(1)

y_predicted_text = []
for i in range(len(y_predicted)):
  if(y_predicted[i] == 0):
    y_predicted_text.append('Peace')
  else:
    y_predicted_text.append('Thumbs Up')

# %%
plt.imshow(x_test[20])
print(y_predicted_text[20])
# Out:
# Peace

# %% [markdown]
# # Evaluate The Model On Test Set

# %%
scores = model.evaluate(x_test, y_test)
# print(model.metrics_names)
print('Evaluating The Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2375 - accuracy: 0.9130
# Evaluating The Model On Test Data
# loss 23.75369369983673
# accuracy 91.30434989929199

# %% [markdown]
# # Confussion Matrix Of CNN Based Classifier

# %%
y_predicted
actual = y_test
conf_mat = confusion_matrix(actual, y_predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
# Increase the font size using the display_labels parameter
displ.plot(xticks_rotation='horizontal', values_format=".0f")

# Increase the font size of the labels
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Increase the font size of the xlabel and ylabel
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Resnet

# %%
NUM_CLASSES = 2
model = Sequential()
model.add(ResNet50(include_top=False, pooling='max', weights="imagenet"))
model.add(Dense(NUM_CLASSES, activation='softmax'))
# ResNet-50 model is already trained, should not be trained
model.layers[0].trainable = False
model.compile(optimizer=keras.optimizers.Adam(
    learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense_1 (Dense)             (None, 2)                 4098
#
# =================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
# Plot and display the model architecture in the notebook
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Convert labels to one-hot encoding
num_classes = 2
y_train_onehot = to_categorical(y_train, num_classes=num_classes)
y_val_onehot = to_categorical(y_val, num_classes=num_classes)
y_test_onehot = to_categorical(y_test, num_classes=num_classes)

# %%
history = model.fit(x_train, y_train_onehot, epochs=100, validation_data=(x_val, y_val_onehot), batch_size=32)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 11s 247ms/step - loss: 0.9756 - accuracy: 0.5043 - val_loss: 0.6075 - val_accuracy: 0.7538
# Epoch 2/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.5558 - accuracy: 0.7299 - val_loss: 0.4895 - val_accuracy: 0.7846
# Epoch 3/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.4985 - accuracy: 0.7573 - val_loss: 0.4570 - val_accuracy: 0.8000
# Epoch 4/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.4572 - accuracy: 0.7880 - val_loss: 0.4371 - val_accuracy: 0.7538
# Epoch 5/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.4352 - accuracy: 0.8051 - val_loss: 0.4157 - val_accuracy: 0.8462
# Epoch 6/100
# 19/19 [==============================] - 2s 105ms/step - loss: 0.4248 - accuracy: 0.7983 - val_loss: 0.4052 - val_accuracy: 0.7846
# Epoch 7/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.4126 - accuracy: 0.8017 - val_loss: 0.3945 - val_accuracy: 0.8154
# Epoch 8/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.4008 - accuracy: 0.8291 - val_loss: 0.4280 - val_accuracy: 0.7846
# Epoch 9/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.4112 - accuracy: 0.8171 - val_loss: 0.3841 - val_accuracy: 0.8154
# Epoch 10/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.3976 - accuracy: 0.8188 - val_loss: 0.3793 - val_accuracy: 0.8154
# Epoch 11/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3727 - accuracy: 0.8410 - val_loss: 0.3747 - val_accuracy: 0.8154
# Epoch 12/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.3572 - accuracy: 0.8513 - val_loss: 0.3925 - val_accuracy: 0.7846
# Epoch 13/100
# 19/19 [==============================] - 2s 106ms/step - loss: 0.3501 - accuracy: 0.8564 - val_loss: 0.3679 - val_accuracy: 0.8154
# Epoch 14/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3426 - accuracy: 0.8615 - val_loss: 0.4050 - val_accuracy: 0.8000
# Epoch 15/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.3512 - accuracy: 0.8564 - val_loss: 0.3620 - val_accuracy: 0.8154
# Epoch 16/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.3486 - accuracy: 0.8530 - val_loss: 0.3954 - val_accuracy: 0.8308
# Epoch 17/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3520 - accuracy: 0.8410 - val_loss: 0.3827 - val_accuracy: 0.8154
# Epoch 18/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3302 - accuracy: 0.8769 - val_loss: 0.3958 - val_accuracy: 0.8154
# Epoch 19/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3517 - accuracy: 0.8513 - val_loss: 0.3713 - val_accuracy: 0.8462
# Epoch 20/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.3197 - accuracy: 0.8615 - val_loss: 0.3580 - val_accuracy: 0.8308
# Epoch 21/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3011 - accuracy: 0.8803 - val_loss: 0.3633 - val_accuracy: 0.8154
# Epoch 22/100
# 19/19 [==============================] - 2s 118ms/step - loss: 0.3003 - accuracy: 0.8752 - val_loss: 0.3675 - val_accuracy: 0.8154
# Epoch 23/100
# 19/19 [==============================] - 2s 119ms/step - loss: 0.3008 - accuracy: 0.8821 - val_loss: 0.3488 - val_accuracy: 0.8462
# Epoch 24/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0
100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1583 - accuracy: 0.9521 - val_loss: 0.2829 - val_accuracy: 0.8615
# Epoch 85/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1503 - accuracy: 0.9504 - val_loss: 0.2870 - val_accuracy: 0.8769
# Epoch 86/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1527 - accuracy: 0.9573 - val_loss: 0.2894 - val_accuracy: 0.8769
# Epoch 87/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1507 - accuracy: 0.9487 - val_loss: 0.2994 - val_accuracy: 0.8769
# Epoch 88/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.1507 - accuracy: 0.9521 - val_loss: 0.4158 - val_accuracy: 0.8308
# Epoch 89/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1683 - accuracy: 0.9436 - val_loss: 0.2898 - val_accuracy: 0.8769
# Epoch 90/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1615 - accuracy: 0.9487 - val_loss: 0.2754 - val_accuracy: 0.8769
# Epoch 91/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.1473 - accuracy: 0.9624 - val_loss: 0.2784 - val_accuracy: 0.8615
# Epoch 92/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1479 - accuracy: 0.9556 - val_loss: 0.2733 - val_accuracy: 0.8769
# Epoch 93/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1479 - accuracy: 0.9504 - val_loss: 0.2676 - val_accuracy: 0.8769
# Epoch 94/100
# 19/19 [==============================] - 2s 118ms/step - loss: 0.1449 - accuracy: 0.9590 - val_loss: 0.2739 - val_accuracy: 0.8769
# Epoch 95/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1423 - accuracy: 0.9607 - val_loss: 0.2665 - val_accuracy: 0.8769
# Epoch 96/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1628 - accuracy: 0.9487 - val_loss: 0.3311 - val_accuracy: 0.8923
# Epoch 97/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1437 - accuracy: 0.9573 - val_loss: 0.3089 - val_accuracy: 0.8923
# Epoch 98/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1586 - accuracy: 0.9504 - val_loss: 0.2638 - val_accuracy: 0.8769
# Epoch 99/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1402 - accuracy: 0.9624 - val_loss: 0.2777 - val_accuracy: 0.8769
# Epoch 100/100
# 19/19 [==============================] - 2s 120ms/step - loss: 0.1401 - accuracy: 0.9573 - val_loss: 0.3179 - val_accuracy: 0.8923

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss', fontsize=16)

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %%
scores = model.evaluate(x_test, y_test_onehot)
# print(model.metrics_names)
print('Evaluating The Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 1s 82ms/step - loss: 0.6201 - accuracy: 0.7205
# Evaluating The Model On Test Data
# loss 62.00878024101257
# accuracy 72.04968929290771

# %%
prediction = model.predict(x_test)
# Out:
# 6/6 [==============================] - 1s 92ms/step

# %%
y_predicted = []
# length = prediction.shape[0]
for i in range(prediction.shape[0]):
  if(prediction[i][0] > prediction[i][1]):
    y_predicted.append(0)
  else:
    y_predicted.append(1)

# %%
y_predicted
actual = y_test
conf_mat = confusion_matrix(actual, y_predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
# Increase the font size using the display_labels parameter
displ.plot(xticks_rotation='horizontal', values_format=".0f")

# Increase the font size of the labels
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Increase the font size of the xlabel and ylabel
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)

# Show the plot
plt.show()
