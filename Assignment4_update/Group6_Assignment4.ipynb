# %% [markdown]
# # Importing Necessary Modules

# %%
from google.colab import drive
from tensorflow.keras.utils import plot_model
import os
import cv2
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import vgg16
from keras.layers import Conv2D, Input, Dense, Activation, MaxPooling2D, Flatten, AveragePooling2D, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from keras.utils import to_categorical
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Fetching Peace and Thumbs Up Data, Labeling Peace as 0, and Thumbs Up as 1

# %%
#reading data and labeling it
DIRECTORY = '/content/drive/MyDrive/thumbsup_peace'
CATEGORIES = ['peace_test', 'peace_train', 'thumbsup_test', 'thumbsup_train']
train_data = []
test_data = []
test_count = 0
train_count = 0
for category in CATEGORIES:
  folder = os.path.join(DIRECTORY, category)
  label = CATEGORIES.index(category) // 2
  # print(label)
  splited_name = category.split('_')
  # print(splited_name[1])

  if(splited_name[1] == "train"):
    # print(category)
      for img in os.listdir(folder):
        image = os.path.join(folder, img)
        image_arr = cv2.imread(image)
        image_arr = cv2.resize(image_arr, (224, 224))
        train_data.append([image_arr, label])
        train_count = train_count+1
  else:
    # print("test")
    for img in os.listdir(folder):
      image = os.path.join(folder, img)
      image_arr = cv2.imread(image)
      image_arr = cv2.resize(image_arr, (224, 224))
      test_data.append([image_arr, label])
      test_count = test_count+1

print('Number of total train data: ', train_count)
print('Number of test data: ', test_count)
# Out:
# Number of total train data:  650
# Number of test data:  161

# %% [markdown]
# # Making np array X_train_val and Y_train_val from train data

# %%
#making x and y from read data and label
random.shuffle(train_data)
x_train_val = []
y_train_val = []

for features,label in train_data:
  x_train_val.append(features)
  y_train_val.append(label)

#converitn x and y list to np array
x_train_val = np.array(x_train_val)
y_train_val = np.array(y_train_val)

# %% [markdown]
# # Making np array x_tes and y_test from test data

# %%
#making x and y from read data and label
random.shuffle(test_data)
x_test = []
y_test = []

for features,label in test_data:
  x_test.append(features)
  y_test.append(label)

#converitn x and y list to np array
x_test = np.array(x_test)
y_test = np.array(y_test)
print(len(y_test))
# Out:
# 161

# %% [markdown]
# # Plotting X_train_val

# %%
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_train_val Intensities Before Normalization')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# # Plotting X_test

# %%
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_test Intensities Before Normalization')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# #Normalizing x_train_val and Plotting

# %%
#normalizing x
x_train_val = x_train_val/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_train_val Pixel Intensities After Normalization')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# #Normalizing x_test and Plotting

# %%
#normalizing x
x_test = x_test/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_test Pixel Intensities After Normalization')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# # Splitting Train and Validation Set

# %%
# x_train, x_val, y_train, y_val  = train_test_split(x_train_val, y_train_val, test_size=0.1)
x_train = x_train_val[:int(len(x_train_val)*.9)]
x_val = x_train_val[-int(len(x_train_val)*.1):]
y_train = y_train_val[:int(len(y_train_val)*.9)]
y_val = y_train_val[-int(len(y_train_val)*.1):]

# %% [markdown]
# # Plotting y_train, y_val and y_test

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_train, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Train Set')
plt.xlabel('Class       Peace(0)          ThumbsUp(1)')
plt.ylabel('Number Of Objects In Each Class')
plt.grid('true')

# Get the counts of objects in each class
counts = np.bincount(y_train)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_val, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Validation Set')
plt.xlabel('Class       Peace(0)          ThumbsUp(1)')
plt.ylabel('Number Of Objects In Each Class')
plt.grid('true')
counts = np.bincount(y_val)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_test, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Test Set')
plt.xlabel('Class       Peace(0)          ThumbsUp(1)')
plt.ylabel('Number Of Objects In Each Class')
plt.grid('true')
counts = np.bincount(y_test)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Printing The Shapes of Train, Test and Validation Data

# %%
print('Shape of x_train', np.shape(x_train))
print('Shape of x_val', np.shape(x_val))
print('Shape of x_test', np.shape(x_test))
print('Shape of y_train', np.shape(y_train))
print('Shape of y_val', np.shape(y_val))
print('Shape of y_test', np.shape(y_test))
# Out:
# Shape of x_train (585, 224, 224, 3)
# Shape of x_val (65, 224, 224, 3)
# Shape of x_test (161, 224, 224, 3)
# Shape of y_train (585,)
# Shape of y_val (65,)
# Shape of y_test (161,)

# %% [markdown]
# # My Custom Neural Network

# %%
# Convert labels to one-hot encoding
num_classes = 2
y_train_onehot = to_categorical(y_train, num_classes=num_classes)
y_val_onehot = to_categorical(y_val, num_classes=num_classes)
y_test_onehot = to_categorical(y_test, num_classes=num_classes)

# %%
inputs = Input((224,224, 3), name='input')

# Block 1
x_custom = Conv2D(32, (3, 3), activation='relu', padding='same', name='block1_conv1_custom')(inputs)
x_custom = Conv2D(32, (3, 3), activation='relu', padding='same', name='block1_conv2_custom')(x_custom)
x_custom = MaxPooling2D((2, 2), name='block1_pool_custom')(x_custom)

# Block 2
x_custom = Conv2D(64, (3, 3), activation='relu', padding='same', name='block2_conv1_custom')(x_custom)
x_custom = Conv2D(64, (3, 3), activation='relu', padding='same', name='block2_conv2_custom')(x_custom)
x_custom = MaxPooling2D((2, 2), name='block2_pool_custom')(x_custom)

# Block 3
x_custom = Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv1_custom')(x_custom)
x_custom = Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv2_custom')(x_custom)
x_custom = Conv2D(128, (3, 3), activation='relu', padding='same', name='block3_conv3_custom')(x_custom)
x_custom = AveragePooling2D((2, 2), name='block3_avg_pool_custom')(x_custom)

# Flatten
x_custom = Flatten(name='flatten_custom')(x_custom)
x_custom = Dense(512, activation='relu', name='fc1_custom')(x_custom)
x_custom = Dense(256, activation='relu', name='fc2_custom')(x_custom)

# Output
outputs = Dense(2, activation='softmax', name='predictions_custom')(x_custom)

# Custom CNN model
model = Model(inputs, outputs, name='cnn_model')
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 224, 224, 3)]     0
#
#  block1_conv1_custom (Conv2  (None, 224, 224, 32)      896
#  D)
#
#  block1_conv2_custom (Conv2  (None, 224, 224, 32)      9248
#  D)
#
#  block1_pool_custom (MaxPoo  (None, 112, 112, 32)      0
#  ling2D)
#
#  block2_conv1_custom (Conv2  (None, 112, 112, 64)      18496
#  D)
#
#  block2_conv2_custom (Conv2  (None, 112, 112, 64)      36928
#  D)
#
#  block2_pool_custom (MaxPoo  (None, 56, 56, 64)        0
#  ling2D)
#
#  block3_conv1_custom (Conv2  (None, 56, 56, 128)       73856
#  D)
#
#  block3_conv2_custom (Conv2  (None, 56, 56, 128)       147584
#  D)
#
#  block3_conv3_custom (Conv2  (None, 56, 56, 128)       147584
#  D)
#
#  block3_avg_pool_custom (Av  (None, 28, 28, 128)       0
#  eragePooling2D)
#
#  flatten_custom (Flatten)    (None, 100352)            0
#
#  fc1_custom (Dense)          (None, 512)               51380736
#
#  fc2_custom (Dense)          (None, 256)               131328
#
#  predictions_custom (Dense)  (None, 2)                 514
#
# =================================================================
# Total params: 51947170 (198.16 MB)
# Trainable params: 51947170 (198.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Showing The Model Architecture

# %%
# Plot and display the model architecture in the notebook
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Trainning The model with x and y

# %%
history = model.fit(x_train, y_train_onehot, epochs=15, validation_data=(x_val, y_val_onehot), batch_size=64)
# Out:
# Epoch 1/15
# 10/10 [==============================] - 6s 315ms/step - loss: 0.6942 - accuracy: 0.5179 - val_loss: 0.6915 - val_accuracy: 0.5231
# Epoch 2/15
# 10/10 [==============================] - 3s 277ms/step - loss: 0.6842 - accuracy: 0.5863 - val_loss: 0.6811 - val_accuracy: 0.5077
# Epoch 3/15
# 10/10 [==============================] - 3s 289ms/step - loss: 0.6399 - accuracy: 0.6137 - val_loss: 0.5929 - val_accuracy: 0.6923
# Epoch 4/15
# 10/10 [==============================] - 3s 285ms/step - loss: 0.4907 - accuracy: 0.7949 - val_loss: 0.4503 - val_accuracy: 0.7846
# Epoch 5/15
# 10/10 [==============================] - 3s 291ms/step - loss: 0.3933 - accuracy: 0.8274 - val_loss: 0.3055 - val_accuracy: 0.8462
# Epoch 6/15
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2990 - accuracy: 0.8667 - val_loss: 0.2941 - val_accuracy: 0.8615
# Epoch 7/15
# 10/10 [==============================] - 3s 298ms/step - loss: 0.2489 - accuracy: 0.8957 - val_loss: 0.2746 - val_accuracy: 0.8769
# Epoch 8/15
# 10/10 [==============================] - 3s 305ms/step - loss: 0.2880 - accuracy: 0.8872 - val_loss: 0.3280 - val_accuracy: 0.8769
# Epoch 9/15
# 10/10 [==============================] - 3s 288ms/step - loss: 0.2425 - accuracy: 0.9111 - val_loss: 0.4339 - val_accuracy: 0.7692
# Epoch 10/15
# 10/10 [==============================] - 3s 290ms/step - loss: 0.2249 - accuracy: 0.9214 - val_loss: 0.3328 - val_accuracy: 0.8462
# Epoch 11/15
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1929 - accuracy: 0.9265 - val_loss: 0.1887 - val_accuracy: 0.9231
# Epoch 12/15
# 10/10 [==============================] - 3s 301ms/step - loss: 0.1350 - accuracy: 0.9470 - val_loss: 0.2686 - val_accuracy: 0.8769
# Epoch 13/15
# 10/10 [==============================] - 3s 287ms/step - loss: 0.1846 - accuracy: 0.9145 - val_loss: 0.2870 - val_accuracy: 0.8769
# Epoch 14/15
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1546 - accuracy: 0.9385 - val_loss: 0.2118 - val_accuracy: 0.9231
# Epoch 15/15
# 10/10 [==============================] - 3s 279ms/step - loss: 0.1069 - accuracy: 0.9556 - val_loss: 0.2354 - val_accuracy: 0.8769

# %%
performance_dict = history.history
print(performance_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Check The Learning Curves

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss')

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# # Evaluate The Model On Validation Set

# %%
scores = model.evaluate(x_val, y_val_onehot)
# print(model.metrics_names)
print('Evaluating The Model On Validation Data')
print(model.metrics_names[1], scores[1]*100)
# Out:
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2354 - accuracy: 0.8769
# Evaluating The Model On Validation Data
# accuracy 87.69230842590332

# %% [markdown]
# # Check What the model actually predicts In Validation Data

# %%
plt.imshow(x_val[26])
print(y_val[26])
# Out:
# 1

# %% [markdown]
# # Check What the model predicts in Test data

# %%
prediction = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 34ms/step

# %%
prediction[1]
# Out:
# array([0.9833107 , 0.01668929], dtype=float32)

# %%
y_test[1]
# Out:
# 0

# %%
y_predicted = []
# length = prediction.shape[0]
for i in range(prediction.shape[0]):
  if(prediction[i][0] > prediction[i][1]):
    y_predicted.append(0)
  else:
    y_predicted.append(1)

y_predicted_text = []
for i in range(len(y_predicted)):
  if(y_predicted[i] == 0):
    y_predicted_text.append('Peace')
  else:
    y_predicted_text.append('Thumbs Up')

# %%
plt.imshow(x_test[20])
print(y_predicted_text[20])
# Out:
# Thumbs Up

# %% [markdown]
# # Evaluate The Model On Test Set

# %%
scores = model.evaluate(x_test, y_test_onehot)
# print(model.metrics_names)
print('Evaluating The Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4317 - accuracy: 0.8137
# Evaluating The Model On Test Data
# loss 43.17491352558136
# accuracy 81.36646151542664

# %% [markdown]
# # Confussion Matrix Of CNN Based Classifier

# %%
y_predicted
actual = y_test
conf_mat = confusion_matrix(actual, y_predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot()

# %% [markdown]
# # A fully connected neural network-based binary classifier

# %%
# Define the input layer
inputs = Input((224, 224, 3), name='input')

x = Flatten()(inputs)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
fcnn_model = Model(inputs, outputs, name='FCNN')
fcnn_model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
fcnn_model.summary()
# Out:
# Model: "FCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 224, 224, 3)]     0
#
#  flatten (Flatten)           (None, 150528)            0
#
#  dense (Dense)               (None, 32)                4816928
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4821153 (18.39 MB)
# Trainable params: 4821153 (18.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Plot and display the model architecture in the notebook
plot_model(fcnn_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
history = fcnn_model.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val), batch_size=16)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 5s 74ms/step - loss: 1.8225 - accuracy: 0.5214 - val_loss: 0.8605 - val_accuracy: 0.6462
# Epoch 2/50
# 37/37 [==============================] - 2s 64ms/step - loss: 0.9932 - accuracy: 0.5932 - val_loss: 0.6362 - val_accuracy: 0.7077
# Epoch 3/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5846 - accuracy: 0.6957 - val_loss: 0.6047 - val_accuracy: 0.6615
# Epoch 4/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6125 - accuracy: 0.6974 - val_loss: 0.5520 - val_accuracy: 0.7385
# Epoch 5/50
# 37/37 [==============================] - 3s 90ms/step - loss: 0.4173 - accuracy: 0.8000 - val_loss: 0.5310 - val_accuracy: 0.7846
# Epoch 6/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.4921 - accuracy: 0.7846 - val_loss: 0.4892 - val_accuracy: 0.8308
# Epoch 7/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.3411 - accuracy: 0.8581 - val_loss: 0.4710 - val_accuracy: 0.8308
# Epoch 8/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.4201 - accuracy: 0.8393 - val_loss: 0.4621 - val_accuracy: 0.8154
# Epoch 9/50
# 37/37 [==============================] - 2s 64ms/step - loss: 0.2567 - accuracy: 0.9077 - val_loss: 0.5389 - val_accuracy: 0.7385
# Epoch 10/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.2831 - accuracy: 0.8803 - val_loss: 0.5437 - val_accuracy: 0.8000
# Epoch 11/50
# 37/37 [==============================] - 3s 85ms/step - loss: 0.2796 - accuracy: 0.8872 - val_loss: 0.5348 - val_accuracy: 0.8000
# Epoch 12/50
# 37/37 [==============================] - 2s 64ms/step - loss: 0.2324 - accuracy: 0.9179 - val_loss: 0.8037 - val_accuracy: 0.7385
# Epoch 13/50
# 37/37 [==============================] - 2s 60ms/step - loss: 0.2240 - accuracy: 0.9179 - val_loss: 0.5688 - val_accuracy: 0.7692
# Epoch 14/50
# 37/37 [==============================] - 2s 64ms/step - loss: 0.2218 - accuracy: 0.9077 - val_loss: 2.0686 - val_accuracy: 0.5231
# Epoch 15/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6855 - accuracy: 0.7333 - val_loss: 0.5543 - val_accuracy: 0.8000
# Epoch 16/50
# 37/37 [==============================] - 3s 79ms/step - loss: 0.6324 - accuracy: 0.7470 - val_loss: 0.5871 - val_accuracy: 0.7538
# Epoch 17/50
# 37/37 [==============================] - 3s 83ms/step - loss: 0.5388 - accuracy: 0.8188 - val_loss: 0.5730 - val_accuracy: 0.7692
# Epoch 18/50
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6320 - accuracy: 0.6222 - val_loss: 0.7317 - val_accuracy: 0.4462
# Epoch 19/50
# 37/37 [==============================] - 2s 63ms/step - loss: 0.7014 - accuracy: 0.5145 - val_loss: 0.7149 - val_accuracy: 0.4462
# Epoch 20/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6966 - accuracy: 0.5145 - val_loss: 0.7067 - val_accuracy: 0.4462
# Epoch 21/50
# 37/37 [==============================] - 2s 59ms/step - loss: 0.6946 - accuracy: 0.5145 - val_loss: 0.7030 - val_accuracy: 0.4462
# Epoch 22/50
# 37/37 [==============================] - 3s 84ms/step - loss: 0.6935 - accuracy: 0.5145 - val_loss: 0.7017 - val_accuracy: 0.4462
# Epoch 23/50
# 37/37 [==============================] - 3s 73ms/step - loss: 0.6932 - accuracy: 0.5145 - val_loss: 0.7002 - val_accuracy: 0.4462
# Epoch 24/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6995 - val_accuracy: 0.4462
# Epoch 25/50
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6975 - val_accuracy: 0.4462
# Epoch 26/50
# 37/37 [==============================] - 2s 59ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6981 - val_accuracy: 0.4462
# Epoch 27/50
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 28/50
# 37/37 [==============================] - 3s 86ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6974 - val_accuracy: 0.4462
# Epoch 29/50
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6972 - val_accuracy: 0.4462
# Epoch 30/50
# 37/37 [==============================] - 2s 59ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6970 - val_accuracy: 0.4462
# Epoch 31/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6963 - val_accuracy: 0.4462
# Epoch 32/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6967 - val_accuracy: 0.4462
# Epoch 33/50
# 37/37 [==============================] - 3s 68ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6965 - val_accuracy: 0.4462
# Epoch 34/50
# 37/37 [==============================] - 3s 86ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6962 - val_accuracy: 0.4462
# Epoch 35/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6968 - val_accuracy: 0.4462
# Epoch 36/50
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6970 - val_accuracy: 0.4462
# Epoch 37/50
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 38/50
# 37/37 [==============================] - 2s 57ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6962 - val_accuracy: 0.4462
# Epoch 39/50
# 37/37 [==============================] - 3s 75ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 40/50
# 37/37 [==============================] - 3s 80ms/step - loss: 0.6930 - accuracy: 0.5145 - val_loss: 0.6958 - val_accuracy: 0.4462
# Epoch 41/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6932 - accuracy: 0.5145 - val_loss: 0.6971 - val_accuracy: 0.4462
# Epoch 42/50
# 37/37 [==============================] - 3s 84ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 43/50
# 37/37 [==============================] - 3s 68ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 44/50
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 45/50
# 37/37 [==============================] - 3s 88ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6970 - val_accuracy: 0.4462
# Epoch 46/50
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6969 - val_accuracy: 0.4462
# Epoch 47/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6967 - val_accuracy: 0.4462
# Epoch 48/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6965 - val_accuracy: 0.4462
# Epoch 49/50
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6929 - accuracy: 0.5145 - val_loss: 0.6966 - val_accuracy: 0.4462
# Epoch 50/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6969 - val_accuracy: 0.4462

# %% [markdown]
# # Check The Learning Curves for FCNN

# %%
performance_dict = history.history
print(performance_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss')

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# # Check What The Model Actually Predics on Test data

# %%
predicted = fcnn_model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 9ms/step

# %%
predicted[1]
# Out:
# array([0.20552875], dtype=float32)

# %%
y_test[1]
# Out:
# 0

# %% [markdown]
# # Evaluate The FCNN model with Validation Data

# %%
scores = fcnn_model.evaluate(x_val, y_val)
# print(model.metrics_names)
print('Evaluating The FCNN Model On Validation Data')
print(model.metrics_names[1], scores[1]*100)
# Out:
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5330 - accuracy: 0.7385
# Evaluating The FCNN Model On Validation Data
# accuracy 73.84615540504456

# %% [markdown]
# # Evaluate The FCNN with Test Data

# %%
scores = fcnn_model.evaluate(x_test, y_test)
# print(model.metrics_names)
print('Evaluating The FCNN Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4133 - accuracy: 0.8634
# Evaluating The FCNN Model On Test Data
# loss 41.333988308906555
# accuracy 86.33540272712708

# %% [markdown]
# # Confussion Matrix Of FCNN Based Classifier

# %%
# predicted = tf.squeeze(predicted)
predicted = np.array([1 if x >= 0.5 else 0 for x in predicted])
actual = y_test
conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot()
